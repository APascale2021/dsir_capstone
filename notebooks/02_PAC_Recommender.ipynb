# %% [markdown]
# <center><h1>Campaign Finance Capstone: PACs</h1></center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Files

# %%
pacs_2014 = pd.read_csv('../data/pacs/2014_pac_donations.csv')
pacs_2012 = pd.read_csv('../data/pacs/2012_pac_donations.csv')
pacs_2010 = pd.read_csv('../data/pacs/2010_pac_donations.csv')
pacs_2008 = pd.read_csv('../data/pacs/2008_pac_donations.csv')
pacs_2006 = pd.read_csv('../data/pacs/2006_pac_donations.csv')
pacs_2004 = pd.read_csv('../data/pacs/2004_pac_donations.csv')
pacs_2002 = pd.read_csv('../data/pacs/2002_pac_donations.csv')
pacs_2000 = pd.read_csv('../data/pacs/2000_pac_donations.csv')

# %%
pacs = pacs_2014.append([pacs_2012, pacs_2010, pacs_2008, pacs_2006, pacs_2004])
pacs.sort_values(by='amount', ascending=False)
# Out:
#         cycle date_donated     pac_id                                pac_name  \
# 281022   2012      8/14/12  C00490045                  Restore Our Future PAC
# 281023   2012      8/21/12  C00490045                  Restore Our Future PAC
# 266349   2012     10/26/12  C00487363                     American Crossroads
# 268499   2012      10/2/12  C00487363                     American Crossroads
# 267759   2008     10/23/08  C00003418                Republican National Cmte
# ...       ...          ...        ...                                     ...
# 266182   2010       9/1/09  C00003418                Republican National Cmte
# 76616    2004     10/20/04  C00075820  National Republican Congressional Cmte
# 9995     2004      9/21/04  C00010603                       DNC Services Corp
# 263560   2012     12/21/11  C00030718               National Assn of Realtors
# 264436   2008     10/20/08  C00003418                Republican National Cmte
#
#          amount candidate_id industry_code type recip_code direct
# 281022  9856374    N00009638         J1100  24A         OI      I
# 281023  9856374    N00009638         J1100  24A         OI      I
# 266349  9806703    N00009638         J1100  24A         OI      I
# 268499  9071481    N00009638         J1100  24A         OI      I
# 267759  9006927    N00006424         Z5100  24C         RP      I
# ...         ...          ...           ...  ...        ...    ...
# 266182  -140000    N00006424         Z5100  24C         RP      I
# 76616   -150925    N00005233         Z5100  24A         RP      I
# 9995    -152029    N00000245         Z5200  24C         DP      I
# 263560  -207732    N00007099         F4200  24E         PB      I
# 264436  -272858    N00006424         Z5100  24C         RP      I
#
# [1833489 rows x 10 columns]

# %% [markdown]
# Negative numbers are just refunds.

# %%
raw_data = pd.read_csv('../data/RAW_candidates.csv')
raw_data.shape
# Out:
# (67999, 17)

# %%
raw_data['first_last_party'] = [name[:-4] for name in raw_data['first_last_party']]

# Save a copy of just the candidate names and corresponding id numbers
cid_lookup = raw_data[['cid', 'first_last_party']]
cid_lookup = cid_lookup.drop_duplicates('cid')
cid_lookup = cid_lookup.rename(columns={'cid':'id', 'first_last_party':'candidate_name'})
cid_lookup.head()
# Out:
#           id         candidate_name
# 0  N00005009  Richmond A Soluade Sr
# 1  N00000948        Lenora B Fulani
# 2  N00004126       Mark Alan Behnke
# 3  N00004451   Stephen Bonsal Young
# 4  N00001670   Raymond J Clatworthy

# %%
cid_lookup.shape
# Out:
# (26047, 2)

# %%
cid_lookup.to_csv('../data/cid_lookup.csv', index=False)

# %% [markdown]
# ### Separate party committees & candidate committees from PACs

# %%
def candidate_cmte(recip_code):
    r = str(recip_code)
    if (r.startswith('D') or r.startswith('R')) & (not r.endswith('P')):
        return 1
    else:
        return 0

# %%
pacs['recip_code'] = pacs['recip_code'].str.upper()

# Create new column to tag party committees
pacs['party_cmte'] = [1 if str(code).endswith('P') else 0 for code in pacs['recip_code']]

# Create new column to tag candidate committees
pacs['candidate_cmte'] = pacs['recip_code'].apply(candidate_cmte)

# %%
pacs[(pacs['party_cmte']==1)].sort_values(by='amount', ascending=False)
# Out:
#         cycle date_donated     pac_id                                pac_name  \
# 267759   2008     10/23/08  C00003418                Republican National Cmte
# 14249    2004      10/8/04  C00010603                       DNC Services Corp
# 13427    2004      7/28/04  C00010603                       DNC Services Corp
# 10933    2004      8/26/04  C00010603                       DNC Services Corp
# 11865    2004      10/1/04  C00010603                       DNC Services Corp
# ...       ...          ...        ...                                     ...
# 12385    2004      12/6/04  C00010603                       DNC Services Corp
# 266182   2010       9/1/09  C00003418                Republican National Cmte
# 76616    2004     10/20/04  C00075820  National Republican Congressional Cmte
# 9995     2004      9/21/04  C00010603                       DNC Services Corp
# 264436   2008     10/20/08  C00003418                Republican National Cmte
#
#          amount candidate_id industry_code type recip_code direct  party_cmte  \
# 267759  9006927    N00006424         Z5100  24C         RP      I           1
# 14249   8100000    N00008072         Z5200  24A         DP      I           1
# 13427   8000000    N00000245         Z5200  24E         DP      I           1
# 10933   7904589    N00008072         Z5200  24A         DP      I           1
# 11865   7900000    N00008072         Z5200  24A         DP      I           1
# ...         ...          ...           ...  ...        ...    ...         ...
# 12385   -112165    N00000245         Z5200  24E         DP      I           1
# 266182  -140000    N00006424         Z5100  24C         RP      I           1
# 76616   -150925    N00005233         Z5100  24A         RP      I           1
# 9995    -152029    N00000245         Z5200  24C         DP      I           1
# 264436  -272858    N00006424         Z5100  24C         RP      I           1
#
#         candidate_cmte
# 267759               0
# 14249                0
# 13427                0
# 10933                0
# 11865                0
# ...                ...
# 12385                0
# 266182               0
# 76616                0
# 9995                 0
# 264436               0
#
# [64969 rows x 12 columns]

# %%
pacs[(pacs['candidate_cmte']==1)].sort_values(by='amount', ascending=False)
# Out:
#         cycle date_donated     pac_id                       pac_name   amount  \
# 99696    2008      8/28/08  C00431569  Hillary Clinton for President  6466214
# 162613   2008      3/30/07  C00358895             Friends of Hillary  4750000
# 53239    2008      3/30/07  C00347310          Friends of Chris Dodd  4739005
# 158498   2008      3/30/07  C00358895             Friends of Hillary  4000000
# 246646   2010      3/31/10  C00419291            Sestak for Congress  3027534
# ...       ...          ...        ...                            ...      ...
# 53968    2008      6/30/07  C00243428      Andrews for Congress Cmte    -5000
# 7686     2008      7/12/07  C00265389                Judd Gregg Cmte    -5000
# 5589     2014     11/13/13  C00197152           Citizens for Bunning    -5000
# 10326    2010      1/15/09  C00443762           Carraro for Congress   -17200
# 183974   2004      9/30/03  C00364448           Northup for Congress   -18662
#
#        candidate_id industry_code type recip_code direct  party_cmte  \
# 99696     N00000019         Z9999  24K         DN      D           0
# 162613    N00000019         Z9999  24K         DO      D           0
# 53239     N00000581         Z9999  24K         DN      D           0
# 158498    N00000019         Z9999  24K         DO      D           0
# 246646    N00028049         Z9999  24K         DL      D           0
# ...             ...           ...  ...        ...    ...         ...
# 53968     N00025450         Z1200  24K         DW      D           0
# 7686      N00007815         Z1100  24K         RI      D           0
# 5589      N00000286         Z1100  24K         RW      D           0
# 10326     N00015616         Z9999  24K         RN      D           0
# 183974    N00003392         Z9999  24K         RL      D           0
#
#         candidate_cmte
# 99696                1
# 162613               1
# 53239                1
# 158498               1
# 246646               1
# ...                ...
# 53968                1
# 7686                 1
# 5589                 1
# 10326                1
# 183974               1
#
# [58039 rows x 12 columns]

# %%
all_pacs = pacs[(pacs['party_cmte']==0) & (pacs['candidate_cmte']==0)]

all_pacs['date_donated'] = pd.to_datetime(all_pacs['date_donated'])
all_pacs = all_pacs.reset_index()
all_pacs = all_pacs.drop(columns=['index', 'party_cmte', 'candidate_cmte', 'industry_code', 'type', 'direct'])

# %%
# Add columns for PAC issue set
all_pacs['business'] = [1 if str(code).endswith('B') else 0 for code in all_pacs['recip_code']]
all_pacs['labor'] = [1 if str(code).endswith('L') else 0 for code in all_pacs['recip_code']]
all_pacs['issues'] = [1 if str(code).endswith('I') else 0 for code in all_pacs['recip_code']]
all_pacs = all_pacs.drop(columns='recip_code')

# %%
all_pacs
# Out:
#          cycle date_donated     pac_id                              pac_name  \
# 0         2014   2014-09-05  C00485250        America's Natural Gas Alliance
# 1         2014   2013-12-18  C00030718             National Assn of Realtors
# 2         2014   2013-04-04  C00158576      International Longshoremens Assn
# 3         2014   2013-09-06  C00095869             Edison Electric Institute
# 4         2014   2014-05-28  C00412122  Students for a New American Politics
# ...        ...          ...        ...                                   ...
# 1710476   2004   2003-12-12  C00035774        Magazine Publishers of America
# 1710477   2004   2004-03-11  C00035774        Magazine Publishers of America
# 1710478   2004   2004-09-14  C00035774        Magazine Publishers of America
# 1710479   2004   2004-11-03  C00035774        Magazine Publishers of America
# 1710480   2004   2003-06-13  C00035857             Wheeling-Pittsburgh Steel
#
#          amount candidate_id  business  labor  issues
# 0          1000    N00031647         1      0       0
# 1          1000    N00013323         1      0       0
# 2          1500    N00031011         0      1       0
# 3          2000    N00029835         1      0       0
# 4            26    N00035660         0      0       1
# ...         ...          ...       ...    ...     ...
# 1710476    1000    N00002045         1      0       0
# 1710477    2500    N00005892         1      0       0
# 1710478    2000    N00000010         1      0       0
# 1710479     500    N00000491         1      0       0
# 1710480     500    N00001604         1      0       0
#
# [1710481 rows x 9 columns]

# %% [markdown]
# ### Add Candidate Name Lookup Function

# %%
cid_lookup = pd.read_csv('../data/cid_lookup.csv')
cid_lookup
# Out:
#               id         candidate_name
# 0      N00005009  Richmond A Soluade Sr
# 1      N00000948        Lenora B Fulani
# 2      N00004126       Mark Alan Behnke
# 3      N00004451   Stephen Bonsal Young
# 4      N00001670   Raymond J Clatworthy
# ...          ...                    ...
# 26042  N00011680  Helen Ann Mrs Garrels
# 26043  N00012405        James B Hunt Jr
# 26044  N00010938   Victor Scott Tiffany
# 26045  N00037568           Sean Guthrie
# 26046  N00037250         Michael Noland
#
# [26047 rows x 2 columns]

# %%
global cid_dict

# Convert candidate id lookup table to a dictionary
def DF_to_dict(df):
    i = 0
    id_dict = {}

    while i<len(df):
        key = df.iloc[i, 0]
        value = df.iloc[i, 1]
        id_dict[key] = value
        i += 1

    return id_dict

# Return corresponding candidate name per ID reference
def id_lookup(cid):
    if cid in cid_dict.keys():
        return cid_dict[cid]
    else:
        return np.nan

# %%
cid_dict = DF_to_dict(cid_lookup)

# %%
all_pacs['candidate_name'] = [id_lookup(cid) for cid in all_pacs['candidate_id']]

# %%
all_pacs[all_pacs['candidate_name'].isnull()]
# Out:
#          cycle date_donated     pac_id                            pac_name  \
# 7853      2014   2014-02-26  C00015933           Arizona Public Service Co
# 38714     2014   2014-09-08  C00004275               American Bankers Assn
# 148505    2014   2013-05-06  C00390575                      WellCare Group
# 148598    2014   2014-06-03  C00331694                       America Works
# 171731    2014   2014-10-02  C00001198         American Hotel & Motel Assn
# ...        ...          ...        ...                                 ...
# 1682399   2004   2003-01-22  C00362624  California Rice Industry Assn Fund
# 1695877   2004   2003-04-12  C00327577                        Gateway 2000
# 1705446   2004   2003-06-23  C00363879                        Entergy Corp
# 1706857   2004   2003-04-10  C00035535               Consumer Bankers Assn
# 1707148   2004   2003-04-07  C00038612                 Sears, Roebuck & Co
#
#          amount candidate_id  business  labor  issues candidate_name
# 7853      25000          NaN         1      0       0            NaN
# 38714      5000    N00024660         1      0       0            NaN
# 148505    13500          NaN         1      0       0            NaN
# 148598    25000          NaN         0      0       1            NaN
# 171731     1000    N00024660         1      0       0            NaN
# ...         ...          ...       ...    ...     ...            ...
# 1682399    1000          NaN         1      0       0            NaN
# 1695877     500          NaN         1      0       0            NaN
# 1705446    1000          NaN         1      0       0            NaN
# 1706857    1000          NaN         1      0       0            NaN
# 1707148    1000          NaN         1      0       0            NaN
#
# [87 rows x 10 columns]

# %%
# Drop any donations with missing candidate ids
all_pacs = all_pacs.dropna()
all_pacs = all_pacs.reset_index()
all_pacs.drop(columns='index', inplace=True)

# %%
all_pacs.shape
# Out:
# (1708982, 10)

# %% [markdown]
# ---
# # Recommender System

# %%
pac_donations = all_pacs[all_pacs['amount']>0][['pac_name', 'candidate_name', 'amount']]
pac_donations
# Out:
#                                      pac_name   candidate_name  amount
# 0              America's Natural Gas Alliance       Mike Kelly    1000
# 1                   National Assn of Realtors       Sam Graves    1000
# 2            International Longshoremens Assn       Bill Owens    1500
# 3                   Edison Electric Institute  Martin Heinrich    2000
# 4        Students for a New American Politics   Shenna Bellows      26
# ...                                       ...              ...     ...
# 1708977        Magazine Publishers of America        Tom Davis    1000
# 1708978        Magazine Publishers of America        Tom DeLay    2500
# 1708979        Magazine Publishers of America       Dan Burton    2000
# 1708980        Magazine Publishers of America    Susan Collins     500
# 1708981             Wheeling-Pittsburgh Steel    Arlen Specter     500
#
# [1665363 rows x 3 columns]

# %%
pivot = pd.pivot_table(pac_donations, index='pac_name', columns='candidate_name', values='amount')
pivot
# Out:
# candidate_name                            A J Sekhon  Aaron Miller  \
# pac_name
# '96 Leadership PAC                               NaN           NaN
# 1199 SEIU United Healthcare Workers East         NaN           NaN
# 1199SEIU United Healthcare Workers East          NaN           NaN
# 13th Colony Leadership Cmte                      NaN           NaN
# 1776 PAC                                         NaN           NaN
# ...                                              ...           ...
# athenahealth Inc                                 NaN           NaN
# eBay Inc                                         NaN           NaN
# eHealth Inc                                      NaN           NaN
# icPurple                                         NaN           NaN
# vRide Inc                                        NaN           NaN
#
# candidate_name                            Aaron Russo  Aaron Schock  \
# pac_name
# '96 Leadership PAC                                NaN           NaN
# 1199 SEIU United Healthcare Workers East          NaN           NaN
# 1199SEIU United Healthcare Workers East           NaN           NaN
# 13th Colony Leadership Cmte                       NaN           NaN
# 1776 PAC                                          NaN           NaN
# ...                                               ...           ...
# athenahealth Inc                                  NaN           NaN
# eBay Inc                                          NaN           NaN
# eHealth Inc                                       NaN           NaN
# icPurple                                          NaN           NaN
# vRide Inc                                         NaN           NaN
#
# candidate_name                            Aaron Woolf  Abel Maldonado  \
# pac_name
# '96 Leadership PAC                                NaN             NaN
# 1199 SEIU United Healthcare Workers East          NaN             NaN
# 1199SEIU United Healthcare Workers East           NaN             NaN
# 13th Colony Leadership Cmte                       NaN             NaN
# 1776 PAC                                          NaN             NaN
# ...                                               ...             ...
# athenahealth Inc                                  NaN             NaN
# eBay Inc                                          NaN             NaN
# eHealth Inc                                       NaN             NaN
# icPurple                                          NaN             NaN
# vRide Inc                                         NaN             NaN
#
# candidate_name                            Abel Tapia  Ada M Fisher  \
# pac_name
# '96 Leadership PAC                               NaN           NaN
# 1199 SEIU United Healthcare Workers East         NaN           NaN
# 1199SEIU United Healthcare Workers East          NaN           NaN
# 13th Colony Leadership Cmte                      NaN           NaN
# 1776 PAC                                         NaN           NaN
# ...                                              ...           ...
# athenahealth Inc                                 NaN           NaN
# eBay Inc                                         NaN           NaN
# eHealth Inc                                      NaN           NaN
# icPurple                                         NaN           NaN
# vRide Inc                                        NaN           NaN
#
# candidate_name                            Adam Charles Kokesh  \
# pac_name
# '96 Leadership PAC                                        NaN
# 1199 SEIU United Healthcare Workers East                  NaN
# 1199SEIU United Healthcare Workers East                   NaN
# 13th Colony Leadership Cmte                               NaN
# 1776 PAC                                                  NaN
# ...                                                       ...
# athenahealth Inc                                          NaN
# eBay Inc                                                  NaN
# eHealth Inc                                               NaN
# icPurple                                                  NaN
# vRide Inc                                                 NaN
#
# candidate_name                            Adam Clayton Powell IV  ...  \
# pac_name                                                          ...
# '96 Leadership PAC                                           NaN  ...
# 1199 SEIU United Healthcare Workers East                     NaN  ...
# 1199SEIU United Healthcare Workers East                      NaN  ...
# 13th Colony Leadership Cmte                                  NaN  ...
# 1776 PAC                                                     NaN  ...
# ...                                                          ...  ...
# athenahealth Inc                                             NaN  ...
# eBay Inc                                                     NaN  ...
# eHealth Inc                                                  NaN  ...
# icPurple                                                     NaN  ...
# vRide Inc                                                    NaN  ...
#
# candidate_name                            Yolly Roberson  \
# pac_name
# '96 Leadership PAC                                   NaN
# 1199 SEIU United Healthcare Workers East             NaN
# 1199SEIU United Healthcare Workers East              NaN
# 13th Colony Leadership Cmte                          NaN
# 1776 PAC                                             NaN
# ...                                                  ...
# athenahealth Inc                                     NaN
# eBay Inc                                             NaN
# eHealth Inc                                          NaN
# icPurple                                             NaN
# vRide Inc                                            NaN
#
# candidate_name                            York Jay Kleinhandler  \
# pac_name
# '96 Leadership PAC                                          NaN
# 1199 SEIU United Healthcare Workers East                    NaN
# 1199SEIU United Healthcare Workers East                     NaN
# 13th Colony Leadership Cmte                                 NaN
# 1776 PAC                                                    NaN
# ...                                                         ...
# athenahealth Inc                                            NaN
# eBay Inc                                                    NaN
# eHealth Inc                                                 NaN
# icPurple                                                    NaN
# vRide Inc                                                   NaN
#
# candidate_name                            Yvette D. Clarke  \
# pac_name
# '96 Leadership PAC                                     NaN
# 1199 SEIU United Healthcare Workers East               NaN
# 1199SEIU United Healthcare Workers East                NaN
# 13th Colony Leadership Cmte                            NaN
# 1776 PAC                                               NaN
# ...                                                    ...
# athenahealth Inc                                       NaN
# eBay Inc                                               NaN
# eHealth Inc                                            NaN
# icPurple                                               NaN
# vRide Inc                                              NaN
#
# candidate_name                            Yvonne Rayford Brown  Zach Dasher  \
# pac_name
# '96 Leadership PAC                                         NaN          NaN
# 1199 SEIU United Healthcare Workers East                   NaN          NaN
# 1199SEIU United Healthcare Workers East                    NaN          NaN
# 13th Colony Leadership Cmte                                NaN          NaN
# 1776 PAC                                                   NaN          NaN
# ...                                                        ...          ...
# athenahealth Inc                                           NaN          NaN
# eBay Inc                                                   NaN          NaN
# eHealth Inc                                                NaN          NaN
# icPurple                                                   NaN          NaN
# vRide Inc                                                  NaN          NaN
#
# candidate_name                            Zach Wamp  Zachary T. Space  \
# pac_name
# '96 Leadership PAC                              NaN               NaN
# 1199 SEIU United Healthcare Workers East        NaN               NaN
# 1199SEIU United Healthcare Workers East         NaN               NaN
# 13th Colony Leadership Cmte                     NaN               NaN
# 1776 PAC                                        NaN               NaN
# ...                                             ...               ...
# athenahealth Inc                                NaN               NaN
# eBay Inc                                        NaN               NaN
# eHealth Inc                                     NaN               NaN
# icPurple                                        NaN               NaN
# vRide Inc                                       NaN               NaN
#
# candidate_name                            Zack Matheny  Zelma A Blakes  \
# pac_name
# '96 Leadership PAC                                 NaN             NaN
# 1199 SEIU United Healthcare Workers East           NaN             NaN
# 1199SEIU United Healthcare Workers East            NaN             NaN
# 13th Colony Leadership Cmte                        NaN             NaN
# 1776 PAC                                           NaN             NaN
# ...                                                ...             ...
# athenahealth Inc                                   NaN             NaN
# eBay Inc                                           NaN             NaN
# eHealth Inc                                        NaN             NaN
# icPurple                                           NaN             NaN
# vRide Inc                                          NaN             NaN
#
# candidate_name                            Zoe Lofgren
# pac_name
# '96 Leadership PAC                                NaN
# 1199 SEIU United Healthcare Workers East          NaN
# 1199SEIU United Healthcare Workers East           NaN
# 13th Colony Leadership Cmte                       NaN
# 1776 PAC                                          NaN
# ...                                               ...
# athenahealth Inc                                  NaN
# eBay Inc                                      1737.65
# eHealth Inc                                       NaN
# icPurple                                          NaN
# vRide Inc                                         NaN
#
# [6882 rows x 4387 columns]

# %%
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))

# %%
# A distance of 1 is a similarity of 0.
dists = pairwise_distances(sparse_pivot, metric='cosine')
dists
# Out:
# array([[0.        , 1.        , 1.        , ..., 0.9611833 , 1.        ,
#         0.93562625],
#        [1.        , 0.        , 0.978394  , ..., 1.        , 1.        ,
#         1.        ],
#        [1.        , 0.978394  , 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        ...,
#        [0.9611833 , 1.        , 1.        , ..., 0.        , 1.        ,
#         0.98641729],
#        [1.        , 1.        , 1.        , ..., 1.        , 0.        ,
#         1.        ],
#        [0.93562625, 1.        , 1.        , ..., 0.98641729, 1.        ,
#         0.        ]])

# %%
# Similarity is 1 - distance.
similarities = cosine_similarity(sparse_pivot)

# %%
recommender_df = pd.DataFrame(dists, 
                              columns=pivot.index, 
                              index=pivot.index)
recommender_df
# Out:
# pac_name                                  '96 Leadership PAC  \
# pac_name
# '96 Leadership PAC                                  0.000000
# 1199 SEIU United Healthcare Workers East            1.000000
# 1199SEIU United Healthcare Workers East             1.000000
# 13th Colony Leadership Cmte                         0.616604
# 1776 PAC                                            0.988748
# ...                                                      ...
# athenahealth Inc                                    1.000000
# eBay Inc                                            0.832980
# eHealth Inc                                         0.961183
# icPurple                                            1.000000
# vRide Inc                                           0.935626
#
# pac_name                                  1199 SEIU United Healthcare Workers East  \
# pac_name
# '96 Leadership PAC                                                        1.000000
# 1199 SEIU United Healthcare Workers East                                  0.000000
# 1199SEIU United Healthcare Workers East                                   0.978394
# 13th Colony Leadership Cmte                                               1.000000
# 1776 PAC                                                                  1.000000
# ...                                                                            ...
# athenahealth Inc                                                          1.000000
# eBay Inc                                                                  0.971609
# eHealth Inc                                                               1.000000
# icPurple                                                                  1.000000
# vRide Inc                                                                 1.000000
#
# pac_name                                  1199SEIU United Healthcare Workers East  \
# pac_name
# '96 Leadership PAC                                                       1.000000
# 1199 SEIU United Healthcare Workers East                                 0.978394
# 1199SEIU United Healthcare Workers East                                  0.000000
# 13th Colony Leadership Cmte                                              1.000000
# 1776 PAC                                                                 1.000000
# ...                                                                           ...
# athenahealth Inc                                                         1.000000
# eBay Inc                                                                 0.890197
# eHealth Inc                                                              1.000000
# icPurple                                                                 1.000000
# vRide Inc                                                                1.000000
#
# pac_name                                  13th Colony Leadership Cmte  \
# pac_name
# '96 Leadership PAC                                           0.616604
# 1199 SEIU United Healthcare Workers East                     1.000000
# 1199SEIU United Healthcare Workers East                      1.000000
# 13th Colony Leadership Cmte                                  0.000000
# 1776 PAC                                                     0.927444
# ...                                                               ...
# athenahealth Inc                                             1.000000
# eBay Inc                                                     0.870634
# eHealth Inc                                                  0.983705
# icPurple                                                     1.000000
# vRide Inc                                                    0.944208
#
# pac_name                                  1776 PAC  1789 Project PAC  \
# pac_name
# '96 Leadership PAC                        0.988748          0.914169
# 1199 SEIU United Healthcare Workers East  1.000000          1.000000
# 1199SEIU United Healthcare Workers East   1.000000          1.000000
# 13th Colony Leadership Cmte               0.927444          1.000000
# 1776 PAC                                  0.000000          1.000000
# ...                                            ...               ...
# athenahealth Inc                          1.000000          1.000000
# eBay Inc                                  0.878848          1.000000
# eHealth Inc                               0.965107          1.000000
# icPurple                                  1.000000          1.000000
# vRide Inc                                 1.000000          1.000000
#
# pac_name                                  18-29 PAC  1911 United  \
# pac_name
# '96 Leadership PAC                              1.0     1.000000
# 1199 SEIU United Healthcare Workers East        1.0     0.725877
# 1199SEIU United Healthcare Workers East         1.0     0.921181
# 13th Colony Leadership Cmte                     1.0     1.000000
# 1776 PAC                                        1.0     1.000000
# ...                                             ...          ...
# athenahealth Inc                                1.0     1.000000
# eBay Inc                                        1.0     0.955133
# eHealth Inc                                     1.0     1.000000
# icPurple                                        1.0     1.000000
# vRide Inc                                       1.0     1.000000
#
# pac_name                                  19th Star PAC  \
# pac_name
# '96 Leadership PAC                             0.971039
# 1199 SEIU United Healthcare Workers East       1.000000
# 1199SEIU United Healthcare Workers East        1.000000
# 13th Colony Leadership Cmte                    0.984600
# 1776 PAC                                       0.955766
# ...                                                 ...
# athenahealth Inc                               1.000000
# eBay Inc                                       0.885475
# eHealth Inc                                    0.953694
# icPurple                                       1.000000
# vRide Inc                                      0.960815
#
# pac_name                                  1Point Administrative Services  ...  \
# pac_name                                                                  ...
# '96 Leadership PAC                                              1.000000  ...
# 1199 SEIU United Healthcare Workers East                        1.000000  ...
# 1199SEIU United Healthcare Workers East                         1.000000  ...
# 13th Colony Leadership Cmte                                     1.000000  ...
# 1776 PAC                                                        1.000000  ...
# ...                                                                  ...  ...
# athenahealth Inc                                                1.000000  ...
# eBay Inc                                                        0.955133  ...
# eHealth Inc                                                     1.000000  ...
# icPurple                                                        1.000000  ...
# vRide Inc                                                       1.000000  ...
#
# pac_name                                   Zia PAC  Zimmer Inc  Zions Bancorp  \
# pac_name
# '96 Leadership PAC                        0.670028    0.877876       0.971536
# 1199 SEIU United Healthcare Workers East  1.000000    1.000000       1.000000
# 1199SEIU United Healthcare Workers East   1.000000    0.904119       1.000000
# 13th Colony Leadership Cmte               0.731552    0.904018       0.949394
# 1776 PAC                                  1.000000    0.938795       0.851505
# ...                                            ...         ...            ...
# athenahealth Inc                          1.000000    1.000000       1.000000
# eBay Inc                                  0.891767    0.802134       0.785071
# eHealth Inc                               1.000000    0.821072       0.945918
# icPurple                                  1.000000    1.000000       1.000000
# vRide Inc                                 1.000000    0.954009       1.000000
#
# pac_name                                  Zoetis Inc  Zurich Insurance  \
# pac_name
# '96 Leadership PAC                          0.966724          0.734847
# 1199 SEIU United Healthcare Workers East    1.000000          0.977995
# 1199SEIU United Healthcare Workers East     1.000000          1.000000
# 13th Colony Leadership Cmte                 0.976052          0.837335
# 1776 PAC                                    1.000000          0.929293
# ...                                              ...               ...
# athenahealth Inc                            1.000000          1.000000
# eBay Inc                                    0.871774          0.546528
# eHealth Inc                                 0.956469          0.839399
# icPurple                                    1.000000          0.978179
# vRide Inc                                   0.942113          0.846191
#
# pac_name                                  athenahealth Inc  eBay Inc  \
# pac_name
# '96 Leadership PAC                                     1.0  0.832980
# 1199 SEIU United Healthcare Workers East               1.0  0.971609
# 1199SEIU United Healthcare Workers East                1.0  0.890197
# 13th Colony Leadership Cmte                            1.0  0.870634
# 1776 PAC                                               1.0  0.878848
# ...                                                    ...       ...
# athenahealth Inc                                       0.0  1.000000
# eBay Inc                                               1.0  0.000000
# eHealth Inc                                            1.0  0.767555
# icPurple                                               1.0  1.000000
# vRide Inc                                              1.0  0.923945
#
# pac_name                                  eHealth Inc  icPurple  vRide Inc
# pac_name
# '96 Leadership PAC                           0.961183       1.0   0.935626
# 1199 SEIU United Healthcare Workers East     1.000000       1.0   1.000000
# 1199SEIU United Healthcare Workers East      1.000000       1.0   1.000000
# 13th Colony Leadership Cmte                  0.983705       1.0   0.944208
# 1776 PAC                                     0.965107       1.0   1.000000
# ...                                               ...       ...        ...
# athenahealth Inc                             1.000000       1.0   1.000000
# eBay Inc                                     0.767555       1.0   0.923945
# eHealth Inc                                  0.000000       1.0   0.986417
# icPurple                                     1.000000       0.0   1.000000
# vRide Inc                                    0.986417       1.0   0.000000
#
# [6882 rows x 6882 columns]

# %%
q = 'Electric'
pacs = pivot[pivot.index.str.contains(q)].index

for pac in pacs[:5]:
    print(pac)
    print('Average amount donated $', round(pivot.loc[pac, :].mean(), 2))
    print('Number of donations', pivot.T[pac].count())
    print('')
    print('10 most similar orgs:\n')
    similar_orgs = recommender_df[pac].sort_values().index.tolist()
    for i, org in enumerate(similar_orgs[1:11]):
        print(f"{i+1}. {org}")
    print('')
    print('*******************************************************************************************')
    print('')
# Out:
# Aiken Electric Cooperative
# Average amount donated $ 1363.89
# Number of donations 6
#
# 10 most similar orgs:
#
# 1. First Citizens Bancorporation
# 2. Colonial Life & Accident Insurance
# 3. Force Protection Inc
# 4. Inman Mills
# 5. BNFL Inc
# 6. Nuclear Fuel Services
# 7. Sc Peanut Growers Assoc Pac
# 8. South Carolina Credit Union League
# 9. West Main Street Values
# 10. NBSC Corp
#
# *******************************************************************************************
#
# American Electric Power
# Average amount donated $ 1302.65
# Number of donations 415
#
# 10 most similar orgs:
#
# 1. Dominion Resources
# 2. Edison Electric Institute
# 3. Nuclear Energy Institute
# 4. Entergy Corp
# 5. American Gas Assn
# 6. DTE Energy
# 7. SBC Communications
# 8. General Electric
# 9. National Beer Wholesalers Assn
# 10. Energy Future Holdings Corp
#
# *******************************************************************************************
#
# Baltimore Gas & Electric
# Average amount donated $ 1325.87
# Number of donations 267
#
# 10 most similar orgs:
#
# 1. Nuclear Energy Institute
# 2. Edison Electric Institute
# 3. American Gas Assn
# 4. Dominion Resources
# 5. Entergy Corp
# 6. Akin, Gump et al
# 7. Energy Future Holdings Corp
# 8. Exelon Corp
# 9. DTE Energy
# 10. Morrison-Knudsen
#
# *******************************************************************************************
#
# Basin Electric Power Co-op
# Average amount donated $ 1542.48
# Number of donations 37
#
# 10 most similar orgs:
#
# 1. Wyoming ACRE
# 2. Wyoming Refining
# 3. Associated Milk Producers
# 4. Black Hills Corp
# 5. OTTER TAIL POWER COMPANY POLITICAL ACTIO
# 6. Golden Grain Energy
# 7. American Sheep Industry Assn
# 8. JR Simplot Co
# 9. Minnesota Power & Light
# 10. Environment America
#
# *******************************************************************************************
#
# Berkeley Electric Cooperative
# Average amount donated $ 1073.81
# Number of donations 7
#
# 10 most similar orgs:
#
# 1. First Citizens Bancorporation
# 2. NBSC Corp
# 3. Right to Work PAC
# 4. Environmental Majority
# 5. Colonial Life & Accident Insurance
# 6. Sc Peanut Growers Assoc Pac
# 7. South Carolina Citizens for Life
# 8. Aiken Electric Cooperative
# 9. South Forward IE PAC
# 10. American Herbal Products Assn
#
# *******************************************************************************************
