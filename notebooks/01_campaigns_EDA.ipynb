# %% [markdown]
# <center>
#     <h1>Campaign Finance Capstone Project</h1>
#     <h3>Exploratory Data Analysis</h3><br>
#     <h5>Encompasses all federal races from 1990-2016</h5>
# </center>

# %% [markdown]
# ## Problem Statement:
#
# To predict the amount of money that needs to be raised to win a congressional or senate race in the next election cycle, based on location and incumbency status.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
file_list = []
root_folder = '../data'

for file in os.listdir(root_folder):
    file_list.append(file.split('.csv')[0]) #import the filenames of all spreadsheets in dataset
    
file_list
# Out:
# ['fec_api_committees',
#  'pac_to_pacs',
#  'individual_contributions',
#  'committees',
#  'pacs',
#  'candidates',
#  'backers',
#  'industry_codes',
#  'politicians',
#  'pac_records']

# %%
# Read in all .csv files to their own DataFrames
fec_api_committees = pd.read_csv(f"{root_folder}/{file_list[0]}.csv")
pac_to_pacs = pd.read_csv(f"{root_folder}/{file_list[1]}.csv", low_memory=False)
individual_contributions = pd.DataFrame()
committees = pd.read_csv(f"{root_folder}/{file_list[3]}.csv")
pacs = pd.read_csv(f"{root_folder}/{file_list[4]}.csv", low_memory=False)
candidates = pd.read_csv(f"{root_folder}/{file_list[5]}.csv")
backers = pd.read_csv(f"{root_folder}/{file_list[6]}.csv")
industry_codes = pd.read_csv(f"{root_folder}/{file_list[7]}.csv")
politicians = pd.read_csv(f"{root_folder}/{file_list[8]}.csv")
pac_records = pd.read_csv(f"{root_folder}/{file_list[9]}.csv")

# %%
# List of DataFrames
DB_list = [fec_api_committees, pac_to_pacs, individual_contributions, committees, pacs, candidates,
           backers, industry_codes, politicians, pac_records]

# %%
def add_commas(number): # For DataFrame.shape formatting
    n = str(number)
    
    if len(n)>6:
        return n[:-6]+','+n[-6:-3]+','+n[-3:]
    elif len(n)>3:
        return n[:-3]+','+n[-3:]
    else:
        return number

# %% [markdown]
# ---
# # Overview of all spreadsheets in dataset
# #### Contains a printout of the shapes of all DataFrames, as well as column headers. The individual contributions file is processed in a separate notebook.

# %%
for i, DB in enumerate(DB_list):
    print(str(i+1)+'. '+file_list[i])
    print(f"[{add_commas(DB.shape[0])} rows - {DB.shape[1]} cols]")
    print('--------')
    print(list(DB.columns))
    print()
# Out:
# 1. fec_api_committees
# [45,507 rows - 13 cols]
# --------
# ['id', 'cid', 'created_at', 'updated_at', 'cycle', 'individual_unitemized_contributions', 'individual_itemized_contributions', 'individual_contributions', 'designation', 'organization_type', 'name', 'committee_id', 'committee_type']
#
# 2. pac_to_pacs
# [1,083,525 rows - 25 cols]
# --------
# ['id', 'cycle', 'fec_rec_no', 'filer_id', 'donor_committee', 'contrib_lend_trans', 'city', 'state', 'zip', 'fec_occ_emp', 'prim_code', 'date', 'amount', 'recipient_id', 'party', 'other_id', 'recip_code', 'recip_prim_code', 'amend', 'report', 'pg', 'microfilm', 'type', 'real_code', 'source']
#
# 3. individual_contributions
# [0 rows - 0 cols]
# --------
# []
#
# 4. committees
# [157,542 rows - 15 cols]
# --------
# ['id', 'cycle', 'committee_id', 'pac_short', 'affiliate', 'ultorg', 'recip_id', 'recip_code', 'fec_cand_id', 'party', 'prim_code', 'source', 'sensitive', 'foreign_owned', 'active']
#
# 5. pacs
# [3,539,657 rows - 11 cols]
# --------
# ['id', 'cycle', 'fec_rec_no', 'pac_id', 'cid', 'amount', 'date', 'real_code', 'type', 'di', 'fec_cand_id']
#
# 6. candidates
# [67,999 rows - 17 cols]
# --------
# ['id', 'cycle', 'fec_cand_id', 'cid', 'first_last_party', 'party', 'dist_id_run_for', 'dist_id_currently_held', 'current_candidate', 'cycle_candidate', 'crpico', 'recip_code', 'nopacs', 'raised_from_pacs', 'raised_from_individuals', 'raised_total', 'raised_unitemized']
#
# 7. backers
# [370 rows - 5 cols]
# --------
# ['id', 'cid', 'name', 'backer_level', 'kickstarter']
#
# 8. industry_codes
# [444 rows - 7 cols]
# --------
# ['id', 'category_code', 'category_name', 'industry_code', 'industry_name', 'sector', 'sector_long']
#
# 9. politicians
# [26,047 rows - 3 cols]
# --------
# ['id', 'cid', 'name']
#
# 10. pac_records
# [44,628 rows - 13 cols]
# --------
# ['id', 'committee_id', 'pac_short', 'affiliate', 'ultorg', 'recip_id', 'recip_code', 'fec_cand_id', 'party', 'prim_code', 'source', 'sensitive', 'foreign_owned']

# %% [markdown]
# ---
# # The Candidates
# #### Quick data cleaning and filtering by key variables -- political party, win/lose, campaign level (Congressional, Senate, Presidential), and total money raised

# %%
candidates['first_last_party'] = [str(name)[0:-4] for name in candidates['first_last_party']]

# %%
set([code[-1] for code in candidates['recip_code']])
# Out:
# {' ', 'C', 'I', 'L', 'N', 'O', 'W', 'l', 'w'}

# %%
set([code for code in candidates['crpico']])
# Out:
# {' ', '3', 'C', 'I', 'N', 'O', 'R', 'U', 'Y'}

# %%
incumbent = []

for code in candidates['crpico']:
    letter = str(code).upper()[-1]
    if letter == 'I': #incumbent
        incumbent.append('y')
    elif letter in ['C', 'O', 'N']: #challenger, open-seat, or non-incumbent
        incumbent.append('n')
    else:
        incumbent.append(np.nan)
        
candidates['incumbent'] = incumbent

# %%
win = []

for code in candidates['recip_code']:
    letter = str(code).upper()[-1]
    if letter == 'W': #won
        win.append(1)
    elif letter == 'L': #lost
        win.append(0)
    else:
        win.append(np.nan)
        
candidates['win'] = win

# %%
campaign = []

for dist in candidates['dist_id_run_for']:
    if str(dist) == 'PRES':
        campaign.append('PRES')
    elif str(dist)[-2] == 'S':
        campaign.append('SEN')
    else:
        campaign.append('REP')
        
candidates['campaign'] = campaign

# %%
# Percent of Congressional, Senate, and Presidential Races
candidates['campaign'].value_counts(normalize=True)
# Out:
# REP     0.752438
# SEN     0.157841
# PRES    0.089722
# Name: campaign, dtype: float64

# %%
cols_to_filter = [
    'cycle', 'campaign', 'first_last_party', 'party', 'incumbent', 'dist_id_run_for', 'win', 'raised_total']

# %%
# Winning Republican Congressional Candidatess
candidates[
    (candidates['campaign']=='REP')&(candidates['win']==1)&(candidates['party']=='R')
][cols_to_filter].sort_values(by='cycle', ascending=False)
# Out:
#        cycle campaign   first_last_party party incumbent dist_id_run_for  win  \
# 7623    2014      REP  John J. Duncan Jr     R         y            TN02  1.0
# 22437   2014      REP    Bruce Westerman     R         n            AR04  1.0
# 22381   2014      REP          Bob Gibbs     R         y            OH07  1.0
# 22386   2014      REP         Jim Jordan     R         y            OH04  1.0
# 22393   2014      REP      Thomas Massie     R         y            KY04  1.0
# ...      ...      ...                ...   ...       ...             ...  ...
# 44991   1990      REP      Gary A Franks     R         n            CT05  1.0
# 44996   1990      REP  Richard D Nichols     R         n            KS05  1.0
# 45035   1990      REP      Norman F Lent     R         y            NY04  1.0
# 19714   1990      REP       Andy Ireland     R         y            FL10  1.0
# 25801   1990      REP   Clyde C Holloway     R         y            LA08  1.0
#
#        raised_total
# 7623         459931
# 22437       1104034
# 22381       1074371
# 22386        933080
# 22393        629627
# ...             ...
# 44991        445848
# 44996        310341
# 45035        458103
# 19714        477706
# 25801        502450
#
# [2867 rows x 8 columns]

# %%
# Losing Republican Congressional Candidatess
candidates[
    (candidates['campaign']=='REP')&(candidates['win']==0)&(candidates['party']=='R')
][cols_to_filter].sort_values(by='cycle', ascending=False)
# Out:
#        cycle campaign               first_last_party party incumbent  \
# 575     2016      REP                  Daniel Sparks     R         n
# 41439   2016      REP                    Mike Tagert     R         n
# 9364    2016      REP                    Ed Holliday     R         n
# 13750   2016      REP                  Starner Jones     R         n
# 10875   2016      REP               Quentin Whitwell     R         n
# ...      ...      ...                            ...   ...       ...
# 16196   1990      REP                 Karl N Snow Jr     R         n
# 6884    1990      REP  William Joseph (Dub) Lawrence     R         n
# 16238   1990      REP            J Kenneth Blackwell     R         n
# 6840    1990      REP             Robert F Rivard Jr     R         n
# 23700   1990      REP                  Bob Duckworth     R         n
#
#       dist_id_run_for  win  raised_total
# 575              MS01  0.0         18133
# 41439            MS01  0.0        448785
# 9364             MS01  0.0        122627
# 13750            MS01  0.0        140858
# 10875            MS01  0.0        213814
# ...               ...  ...           ...
# 16196            UT03  0.0        362177
# 6884             UT01  0.0           410
# 16238            OH01  0.0       1052797
# 6840             GA07  0.0          5005
# 23700            MD04  0.0         10362
#
# [7618 rows x 8 columns]

# %%
# Winning Democratic Congressional Candidatess
candidates[
    (candidates['campaign']=='REP')&(candidates['win']==1)&(candidates['party']=='D')
][cols_to_filter].sort_values(by='cycle', ascending=False)
# Out:
#        cycle campaign          first_last_party party incumbent  \
# 13767   2014      REP            Elizabeth Esty     D         y
# 43229   2014      REP       Dutch Ruppersberger     D         y
# 43248   2014      REP                Alma Adams     D         n
# 13813   2014      REP  Debbie Wasserman Schultz     D         y
# 13821   2014      REP              Norma Torres     D         n
# ...      ...      ...                       ...   ...       ...
# 8514    1990      REP             Gary A Condit     D         y
# 19712   1990      REP                 JJ Pickle     D         y
# 19672   1990      REP               Ron de Lugo     D         y
# 19670   1990      REP                Tom Lantos     D         y
# 38225   1990      REP            Peter Hoagland     D         y
#
#       dist_id_run_for  win  raised_total
# 13767            CT05  1.0       2992818
# 43229            MD02  1.0        906371
# 43248            NC12  1.0        975536
# 13813            FL23  1.0       2543524
# 13821            CA35  1.0        476700
# ...               ...  ...           ...
# 8514             CA15  1.0       1027198
# 19712            TX10  1.0        623918
# 19672            VI00  1.0         23650
# 19670            CA11  1.0        875093
# 38225            NE02  1.0        926634
#
# [2917 rows x 8 columns]

# %%
# Winning Republican Senate Candidatess
candidates[
    (candidates['campaign']=='SEN')&(candidates['win']==1)&(candidates['party']=='R')
][cols_to_filter].sort_values(by='cycle', ascending=False)
# Out:
#        cycle campaign        first_last_party party incumbent dist_id_run_for  \
# 51060   2014      SEN           Steven Daines     R         n            MTS2
# 19113   2014      SEN              Joni Ernst     R         n            IAS2
# 26384   2014      SEN         Lamar Alexander     R         y            TNS2
# 43243   2014      SEN    Shelley Moore Capito     R         n            WVS2
# 6070    2014      SEN          Lindsey Graham     R         y            SCS2
# ...      ...      ...                     ...   ...       ...             ...
# 23574   1990      SEN  Nancy Landon Kassebaum     R         y            KSS1
# 46993   1990      SEN               Bob Smith     R         n            NHS2
# 31578   1990      SEN          Larry Pressler     R         y            SDS2
# 38266   1990      SEN          Strom Thurmond     R         y            SCS2
# 16169   1990      SEN         William S Cohen     R         y            MES2
#
#        win  raised_total
# 51060  1.0       5303023
# 19113  1.0      16206720
# 26384  1.0       6229500
# 43243  1.0       6868714
# 6070   1.0       7995142
# ...    ...           ...
# 23574  1.0        678346
# 46993  1.0       1847753
# 31578  1.0       2673415
# 38266  1.0       1458327
# 16169  1.0       1996606
#
# [286 rows x 8 columns]

# %%
# Winning Democratic Senate Candidatess
candidates[
    (candidates['campaign']=='SEN')&(candidates['win']==1)&(candidates['party']=='D')
][cols_to_filter].sort_values(by='cycle', ascending=False)
# Out:
#        cycle campaign    first_last_party party incumbent dist_id_run_for  \
# 767     2014      SEN         Mark Warner     D         y            VAS2
# 17182   2014      SEN          Al Franken     D         y            MNS1
# 31483   2014      SEN        Brian Schatz     D         y            HIS1
# 28589   2014      SEN           Jack Reed     D         y            RIS2
# 13983   2014      SEN         Chris Coons     D         y            DES2
# ...      ...      ...                 ...   ...       ...             ...
# 31583   1990      SEN          Max Baucus     D         y            MTS2
# 43305   1990      SEN  J Bennett Johnston     D         y            LAS1
# 43306   1990      SEN   Joseph R Biden Jr     D         y            DES2
# 4053    1990      SEN          Carl Levin     D         y            MIS1
# 36355   1990      SEN         David Pryor     D         y            ARS1
#
#        win  raised_total
# 767    1.0      14894451
# 17182  1.0       6884966
# 31483  1.0       6558313
# 28589  1.0       3528287
# 13983  1.0       5042428
# ...    ...           ...
# 31583  1.0       2422886
# 43305  1.0       5515776
# 43306  1.0       1506946
# 4053   1.0       9923387
# 36355  1.0       1660400
#
# [287 rows x 8 columns]

# %%
# If Win is Null, Dropouts ?
candidates[candidates['win'].isna()].sort_values(by='cycle', ascending=False)[cols_to_filter]
# Out:
#        cycle campaign              first_last_party party incumbent  \
# 67998   2016      REP             Mario Diaz-Balart     R         y
# 65218   2016     PRES           Timothy Lee Bearson     R       NaN
# 65198   2016      REP                  Terry Bowman     R       NaN
# 65199   2016      REP              Horace Sheffield     D       NaN
# 65200   2016      REP                Steve Dunwoody     D       NaN
# ...      ...      ...                           ...   ...       ...
# 52294   1990      REP         Blyth William Daylong     D       NaN
# 52295   1990      REP           Rickey Lynn Swinney     U       NaN
# 52296   1990      REP          James Mercer Beasley     I       NaN
# 52297   1990      REP  Robert Derwood (Buck) Ladner     D       NaN
# 52148   1990      REP      George Henry Loeffler Jr     R       NaN
#
#       dist_id_run_for  win  raised_total
# 67998            FL25  NaN        455427
# 65218            PRES  NaN             0
# 65198            MI12  NaN             0
# 65199            MI13  NaN             0
# 65200            MI14  NaN             0
# ...               ...  ...           ...
# 52294            Pres  NaN             0
# 52295            Pres  NaN             0
# 52296            Pres  NaN             0
# 52297            Pres  NaN             0
# 52148            TX25  NaN             0
#
# [38157 rows x 8 columns]

# %%
candidates['raised_mil'] = candidates['raised_total'] / 1_000_000

# %%
# The Incumbency Boost is Extremely Powerful
candidates[
    (candidates['party']=='D') | (candidates['party']=='R')].groupby(by=[
        'campaign', 'party', 'incumbent'])[['win', 'raised_mil']].mean().sort_values(by='incumbent', ascending=False)
# Out:
#                                win  raised_mil
# campaign party incumbent
# PRES     D     y          1.000000   54.048979
#          R     y          0.250000   18.859910
# REP      D     y          0.929304    0.983787
#          R     y          0.945860    1.083461
# SEN      D     y          0.906250    2.770919
#          R     y          0.868545    2.367938
# PRES     D     n          0.111111    7.764400
#          R     n          0.018182    6.042874
# REP      D     n          0.055150    0.201037
#          R     n          0.061595    0.179065
# SEN      D     n          0.078947    1.473403
#          R     n          0.077217    1.360703

# %% [markdown]
# ---
# # Political Action Committees

# %%
# Top corporate donors by millions of dollars
pac_to_pacs['amount_mil'] = pac_to_pacs['amount']/1_000_000
pac_to_pacs.groupby(by='donor_committee')[['amount_mil']].mean().sort_values(by='amount_mil', ascending=False).head(20)
# Out:
#                               amount_mil
# donor_committee
# BANK OF AMERICA, NA            12.000000
# BANK OF GEORGETOWN              6.666667
# AMALGAMATED BANK OF NEW YORK    6.166667
# WELLS FARGO                     6.000000
# SUMMIT BANK                     5.781316
# SMITH, THOMAS                   4.225000
# SOROS, GEORGE                   3.275000
# Feinstein, Dianne               3.180000
# Watts, Mikal                    2.797334
# BING, STEVE                     2.746194
# Romney Victory                  2.629107
# Romney, Mitt                    2.623529
# Bank of America, NA             2.566667
# McCain-Palin 2008               2.324921
# Hull, Blair                     2.216667
# BANK OF AMERICA-LOC             2.092857
# CHAIN BRIDGE BANK               2.000000
# Ciresi, Michael V               2.000000
# GOLDMAN SACHS & CO.             2.000000
# Obama Victory Fund              1.774419
