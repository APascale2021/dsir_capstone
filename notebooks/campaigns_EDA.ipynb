# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
file_list = []
root_folder = '../data'

for file in os.listdir(root_folder):
    file_list.append(file.split('.csv')[0])
    
file_list
# Out:
# ['fec_api_committees',
#  'pac_to_pacs',
#  'individual_contributions',
#  'committees',
#  'pacs',
#  'candidates',
#  'backers',
#  'industry_codes',
#  'politicians',
#  'pac_records']

# %%
fec_api_committees = pd.read_csv(f"{root_folder}/{file_list[0]}.csv")
pac_to_pacs = pd.read_csv(f"{root_folder}/{file_list[1]}.csv", low_memory=False)
individual_contributions = pd.DataFrame()
committees = pd.read_csv(f"{root_folder}/{file_list[3]}.csv")
pacs = pd.read_csv(f"{root_folder}/{file_list[4]}.csv", low_memory=False)
candidates = pd.read_csv(f"{root_folder}/{file_list[5]}.csv")
backers = pd.read_csv(f"{root_folder}/{file_list[6]}.csv")
industry_codes = pd.read_csv(f"{root_folder}/{file_list[7]}.csv")
politicians = pd.read_csv(f"{root_folder}/{file_list[8]}.csv")
pac_records = pd.read_csv(f"{root_folder}/{file_list[9]}.csv")

# %%
DB_list = [fec_api_committees, pac_to_pacs, individual_contributions, committees, pacs, candidates,
           backers, industry_codes, politicians, pac_records]

# %%
def add_commas(number):
    n = str(number)
    
    if len(n)>6:
        return n[:-6]+','+n[-6:-3]+','+n[-3:]
    elif len(n)>3:
        return n[:-3]+','+n[-3:]
    else:
        return number

# %%
for i, DB in enumerate(DB_list):
    print(str(i+1)+'. '+file_list[i])
    print(f"[{add_commas(DB.shape[0])} rows - {DB.shape[1]} cols]")
    print('--------')
    print(list(DB.columns))
    print()
# Out:
# 1. fec_api_committees
# [45,507 rows - 13 cols]
# --------
# ['id', 'cid', 'created_at', 'updated_at', 'cycle', 'individual_unitemized_contributions', 'individual_itemized_contributions', 'individual_contributions', 'designation', 'organization_type', 'name', 'committee_id', 'committee_type']
#
# 2. pac_to_pacs
# [1,083,525 rows - 25 cols]
# --------
# ['id', 'cycle', 'fec_rec_no', 'filer_id', 'donor_committee', 'contrib_lend_trans', 'city', 'state', 'zip', 'fec_occ_emp', 'prim_code', 'date', 'amount', 'recipient_id', 'party', 'other_id', 'recip_code', 'recip_prim_code', 'amend', 'report', 'pg', 'microfilm', 'type', 'real_code', 'source']
#
# 3. individual_contributions
# [0 rows - 0 cols]
# --------
# []
#
# 4. committees
# [157,542 rows - 15 cols]
# --------
# ['id', 'cycle', 'committee_id', 'pac_short', 'affiliate', 'ultorg', 'recip_id', 'recip_code', 'fec_cand_id', 'party', 'prim_code', 'source', 'sensitive', 'foreign_owned', 'active']
#
# 5. pacs
# [3,539,657 rows - 11 cols]
# --------
# ['id', 'cycle', 'fec_rec_no', 'pac_id', 'cid', 'amount', 'date', 'real_code', 'type', 'di', 'fec_cand_id']
#
# 6. candidates
# [67,999 rows - 17 cols]
# --------
# ['id', 'cycle', 'fec_cand_id', 'cid', 'first_last_party', 'party', 'dist_id_run_for', 'dist_id_currently_held', 'current_candidate', 'cycle_candidate', 'crpico', 'recip_code', 'nopacs', 'raised_from_pacs', 'raised_from_individuals', 'raised_total', 'raised_unitemized']
#
# 7. backers
# [370 rows - 5 cols]
# --------
# ['id', 'cid', 'name', 'backer_level', 'kickstarter']
#
# 8. industry_codes
# [444 rows - 7 cols]
# --------
# ['id', 'category_code', 'category_name', 'industry_code', 'industry_name', 'sector', 'sector_long']
#
# 9. politicians
# [26,047 rows - 3 cols]
# --------
# ['id', 'cid', 'name']
#
# 10. pac_records
# [44,628 rows - 13 cols]
# --------
# ['id', 'committee_id', 'pac_short', 'affiliate', 'ultorg', 'recip_id', 'recip_code', 'fec_cand_id', 'party', 'prim_code', 'source', 'sensitive', 'foreign_owned']

# %%
industry_codes.drop(0, axis=0)['sector'].value_counts().sort_values(ascending=False)
# Out:
# Misc Business            102
# Ideology/Single-Issue     45
# Transportation            37
# Finance/Insur/RealEst     35
# Energy/Nat Resource       30
# Health                    30
# Agribusiness              30
# Labor                     30
# Communic/Electronics      27
# Other                     23
# Construction              22
# Defense                    8
# Lawyers & Lobbyists        6
# Non-contribution           5
# Unknown                    5
# Party Cmte                 4
# Joint Candidate Cmtes      3
# Candidate                  1
# Name: sector, dtype: int64

# %%
industry_codes.head()
# Out:
#    id category_code                      category_name industry_code  \
# 0   1       Catcode                            Catname      Catorder
# 1   2         F2600  Private Equity & Investment Firms           F07
# 2   3         D6000      Homeland Security contractors           D03
# 3   4         X9000                Foreign Governments           W07
# 4   5         F2700                        Hedge Funds           F07
#
#              industry_name                 sector  \
# 0                 Industry                 Sector
# 1  Securities & Investment  Finance/Insur/RealEst
# 2             Misc Defense                Defense
# 3                    Other                  Other
# 4  Securities & Investment  Finance/Insur/RealEst
#
#                         sector_long
# 0                       Sector Long
# 1  Finance, Insurance & Real Estate
# 2                           Defense
# 3                             Other
# 4  Finance, Insurance & Real Estate

# %%
backers['backer_level'].value_counts().sort_values(ascending=False)
# Out:
# kickstarter_backer    248
# upstart                50
# house                  48
# senate                 22
# leadership              2
# Name: backer_level, dtype: int64

# %%
win = [code.endswith('W') for code in candidates['recip_code']]
repub = candidates['party']=='R'
lose = [code.endswith('L') for code in candidates['recip_code']]
dem = candidates['party']=='D'
pres = candidates['dist_id_run_for']=='PRES'
cong = candidates['dist_id_run_for']!='PRES'

# %%
# Top Losing Repub Congressional Candidates
candidates[(repub & lose) & cong].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid       first_last_party party  \
# 12345   1202   2000   S0NY00303  N00001176       Rick A Lazio (R)     R
# 15515  24484   2010   S0CT00151  N00031165      Linda McMahon (R)     R
# 36004  29890   2012   S0CT00151  N00031165      Linda McMahon (R)     R
# 3983   62510   1998   S0NY00048  N00001158  Alfonse M D'Amato (R)     R
# 37704  21251   2010   S0NV00138  N00027581      Sharron Angle (R)     R
# 11394  30498   2012   S2OH00170  N00033174        Josh Mandel (R)     R
# 12265  24747   2010   S0CA00330  N00031348      Carly Fiorina (R)     R
# 9519   30834   2012   S2TX00361  N00033445  David H. Dewhurst (R)     R
# 17584  13919   2006   S4PA00063  N00001380      Rick Santorum (R)     R
# 36589  51518   1994   S4VA00056  N00002032       Oliver North (R)     R
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 12345            NYS1                   NY02                 Y
# 15515            CTS2                                        Y
# 36004            CTS1                                        Y
# 3983             NYS2                   NYS2                 Y
# 37704            NVS2                                        Y
# 11394            OHS1                                        Y
# 12265            CAS1                                        Y
# 9519             TXS2
# 17584            PAS2                   PAS2                 Y
# 36589            VAS1                                        Y
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 12345               Y      O         RL                4322641.0
# 15515               Y      O         RL                  18663.0
# 36004               Y      O         RL                1044005.0
# 3983                Y      I         RL                4226025.0
# 37704               Y      C         RL                3327104.0
# 11394               Y      C         RL                7818716.0
# 12265               Y      C         RL                7187249.0
# 9519                Y      O         RL                1841775.0
# 17584               Y      I         RL                6285363.0
# 36589               Y      C         RL                 868741.0
#
#        raised_from_individuals  raised_total  raised_unitemized
# 12345               20425037.0      60633230         35885552.0
# 15515               53105984.0      53124647                0.0
# 36004               40295112.0      41597048           257931.0
# 3983                12763172.0      31500718         14511521.0
# 37704               10674490.0      29622426         15620832.0
# 11394               16055250.0      27915260          4041294.0
# 12265               16999197.0      27399423          3212977.0
# 9519                23258414.0      25269758           169569.0
# 17584               14125686.0      24979491          4568442.0
# 36589                3089134.0      24513075         20555200.0

# %%
# Top Winning Repub Congressional Candidates
candidates[(repub & win) & cong].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid          first_last_party party  \
# 4094   52083   1994   S4TX00086  N00005675  Kay Bailey Hutchison (R)     R
# 26157  36876   2014   S2KY00012  N00003389       Mitch McConnell (R)     R
# 30409   7117   2002   S2NC00083  N00008071        Elizabeth Dole (R)     R
# 33562  28075   2012   H0OH08029  N00003675          John Boehner (R)     R
# 7772   23930   2010   S4PA00121  N00001489            Pat Toomey (R)     R
# 35307   7115   2002   S2TX00106  N00024852           John Cornyn (R)     R
# 44611  21780   2010   S0FL00338  N00030612           Marco Rubio (R)     R
# 2082   32540   2014   H0OH08029  N00003675          John Boehner (R)     R
# 9100   22988   2010   H0IL10120  N00012539             Mark Kirk (R)     R
# 42955  24352   2010   S0IL00261  N00012539             Mark Kirk (R)     R
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 4094             TXS2                   TXS2                 Y
# 26157            KYS1                   KYS1                 Y
# 30409            NCS1                                        Y
# 33562            OH08                   OH08                 Y
# 7772             PAS1                                        Y
# 35307            TXS1                                        Y
# 44611            FLS2                                        Y
# 2082             OH08                   OH08                 Y
# 9100             ILS2                   IL10
# 42955            ILS2                   IL10                 Y
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 4094                Y      I         RW                4817703.0
# 26157               Y      I         RW                8372640.0
# 30409               Y      O         RW                3145058.0
# 33562               Y      I         RW                2784227.0
# 7772                Y      O         RW                6001714.0
# 35307               Y      O         RW                4192569.0
# 44611               Y      O         RW                6688686.0
# 2082                Y      I         RW                3232599.0
# 9100                       O         RW                6540608.0
# 42955               Y      O         RW                6540608.0
#
#        raised_from_individuals  raised_total  raised_unitemized
# 4094                 7492333.0      23337780         11027744.0
# 26157               13470866.0      22776329           932823.0
# 30409                7345289.0      21640133         11149786.0
# 33562               12692665.0      21344947          5868055.0
# 7772                11054077.0      21294090          4238299.0
# 35307                7060450.0      19158296          7905277.0
# 44611               11933201.0      18621887                NaN
# 2082                12092238.0      18573508          3248671.0
# 9100                10385171.0      18228030          1302251.0
# 42955               10385171.0      18228030          1302251.0

# %%
# Top Losing Dem Congressional Candidates
candidates[(dem & lose) & cong].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid          first_last_party party  \
# 14938  10982   2004   S4IL00172  N00025738            Blair Hull (D)     D
# 4432   10922   2004   S2NC00109  N00024858      Erskine B Bowles (D)     D
# 28603  37503   2014   S8NC00239  N00029617          Kay R. Hagan (D)     D
# 16980  37473   2014   S8CO00172  N00008051            Mark Udall (D)     D
# 7753   24398   2010   S0PA00434  N00028049  Joseph A. Sestak, Jr (D)     D
# 7752   22875   2010   H6PA07105  N00028049  Joseph A. Sestak, Jr (D)     D
# 5119   14175   2006   S6TN00240  N00003218      Harold E Ford Jr (D)     D
# 35557  13683   2006   H6TN09043  N00003218      Harold E Ford Jr (D)     D
# 7358   15545   2006   S6CT05066  N00028063            Ned Lamont (D)     D
# 20797  37114   2014   S4KY00091  N00035486         Alison Grimes (D)     D
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 14938            ILS2
# 4432             NCS2                                        Y
# 28603            NCS1                   NCS1                 Y
# 16980            COS2                   COS2                 Y
# 7753             PAS1                   PA07                 Y
# 7752             PAS1                   PA07
# 5119             TNS1                   TN09                 Y
# 35557            TNS1                   TN09
# 7358             CTS1                                        Y
# 20797            KYS1                                        Y
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 14938               Y      O         DL                    179.0
# 4432                Y      O         DL                5353192.0
# 28603               Y      I         DL                5480904.0
# 16980               Y      I         DL                6334617.0
# 7753                Y      O         DL                6015497.0
# 7752                       O         DL                6015497.0
# 5119                Y      O         DL                5352292.0
# 35557                      O         DL                5352292.0
# 7358                Y      C         DL                 418474.0
# 20797               Y      C         DL                1363499.0
#
#        raised_from_individuals  raised_total  raised_unitemized
# 14938               22124300.0      22188238            63759.0
# 4432                 8069240.0      21927894          8505462.0
# 28603               10953528.0      21064974          4630542.0
# 16980               10519469.0      20135736          3281650.0
# 7753                10289564.0      18208093          1903032.0
# 7752                10289564.0      18208093          1903032.0
# 5119                11250219.0      18004627          1402116.0
# 35557               11250219.0      18004627          1402116.0
# 7358                16079735.0      17925934          1427725.0
# 20797                9160205.0      17144152          6620448.0

# %%
# Top Winning Dem Congressional Candidates
candidates[(dem & win) & cong].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid      first_last_party party  \
# 11322  30892   2012   S2MA00170  N00033492  Elizabeth Warren (D)     D
# 26812  13908   2006   S0NY00188  N00000019   Hillary Clinton (D)     D
# 26811  15501   2006   P00003392  N00000019   Hillary Clinton (D)     D
# 22395  22618   2010   S2CA00286  N00006692     Barbara Boxer (D)     D
# 5880   28585   2012   H2OH13033  N00003535     Sherrod Brown (D)     D
# 5879   30259   2012   S6OH00163  N00003535     Sherrod Brown (D)     D
# 32170   1858   2000   S0NY00188  N00000019   Hillary Clinton (D)     D
# 13297   9252   2004   S2CA00286  N00006692     Barbara Boxer (D)     D
# 24124  37136   2014   S4MA00028  N00000270         Ed Markey (D)     D
# 16556  30501   2012   S2VA00142  N00033177         Tim Kaine (D)     D
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 11322            MAS1                                        Y
# 26812            NYS1                   NYS1                 Y
# 26811            NYS1                   NYS1
# 22395            CAS1                   CAS1                 Y
# 5880             OHS1                   OHS1
# 5879             OHS1                   OHS1                 Y
# 32170            NYS1                                        Y
# 13297            CAS1                   CAS1                 Y
# 24124            MAS2                   MAS2                 Y
# 16556            VAS1                                        Y
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 11322               Y      C         DW                3203496.0
# 26812               Y      I         DW                1668082.0
# 26811                      I         DW                1668082.0
# 22395               Y      I         DW                7719079.0
# 5880                       I         DW                6565947.0
# 5879                Y      I         DW                6565947.0
# 32170               Y      O         DW                3343382.0
# 13297               Y      I         DW                4800003.0
# 24124               Y      I         DW                5826539.0
# 16556               Y      O         DW                4977456.0
#
#        raised_from_individuals  raised_total  raised_unitemized
# 11322               22485898.0      44724683         19035289.0
# 26812               25363388.0      33690345          6658875.0
# 26811               25363388.0      33690345          6658875.0
# 22395               12692881.0      24179959          3767999.0
# 5880                10663027.0      24082184          6853210.0
# 5879                10663027.0      24082184          6853210.0
# 32170               20262712.0      23768527           162433.0
# 13297                7963428.0      23363069         10599638.0
# 24124               13264679.0      22241873          3150655.0
# 16556               13525638.0      21562195          3059101.0

# %%
# Top Money Raised Dem Pres Candidates
candidates[dem & pres].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid      first_last_party party  \
# 33242  19999   2008   P80003205  N00028836  Lee L Mercer, Jr (D)     D
# 23231  29707   2012   P80003338  N00009638      Barack Obama (D)     D
# 14922  20091   2008   S4IL00180  N00009638      Barack Obama (D)     D
# 14921  20009   2008   P80003338  N00009638      Barack Obama (D)     D
# 9695   10986   2004   S4MA00069  N00000245        John Kerry (D)     D
# 9694   12806   2004   P80000235  N00000245        John Kerry (D)     D
# 32023  64372   2016   S0NY00188  N00000019   Hillary Clinton (D)     D
# 410    65622   2016   P00003392  N00000019   Hillary Clinton (D)     D
# 32102  67930   2016   P60007168  N00000528    Bernie Sanders (D)     D
# 67396  36504   2014   P80003205  N00028836  Lee L Mercer, Jr (D)     D
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 33242            PRES
# 23231            PRES                   PRES                 Y
# 14922            PRES                   ILS2
# 14921            PRES                   ILS2                 Y
# 9695             PRES                   MAS2
# 9694             PRES                   MAS2                 Y
# 32023            PRES
# 410              PRES                                        Y
# 32102            PRES                   VTS1                 Y
# 67396            PRES
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 33242                                DN                   1000.0
# 23231               Y      I         DW               55911229.0
# 14922                      O         DW               65836708.0
# 14921               Y      O         DW               65836708.0
# 9695                       C         DC      Y       116445199.0
# 9694                Y      C         DL      Y       116445199.0
# 32023                      O         DO                 426399.0
# 410                 Y      O         DO                 426399.0
# 32102               Y      O         DO                  86649.0
# 67396                                DN                      NaN
#
#        raised_from_individuals  raised_total  raised_unitemized
# 33242              729005408.0     729006408                NaN
# 23231              322775065.0     613095984        234409690.0
# 14922              389386184.0     455230591             7699.0
# 14921              389386184.0     455230591             7699.0
# 9695               160067123.0     276512322                0.0
# 9694               160067123.0     276512322                0.0
# 32023               60025985.0      82192326         21739942.0
# 410                 60025985.0      82192326         21739942.0
# 32102               19169576.0      74172060         54915835.0
# 67396               72000000.0      72000000                NaN

# %%
# Top Money Raised Repub Pres Candidates
candidates[repub & pres].sort_values(by='raised_total', ascending=False).head(10)
# Out:
#           id  cycle fec_cand_id        cid        first_last_party party  \
# 43213  29709   2012   P80003353  N00000286         Mitt Romney (R)     R
# 37682  19970   2008   P80002801  N00006424         John McCain (R)     R
# 42665  20147   2008   S6AZ00019  N00006424         John McCain (R)     R
# 11245  12906   2004   P00003335  N00008072       George W Bush (R)     R
# 39207   1590   2000   P00003335  N00008072       George W Bush (R)     R
# 14064   1750   2000   P60003852  N00000802        Steve Forbes (R)     R
# 3036   20103   2008   S4MA00143  N00000286         Mitt Romney (R)     R
# 3037   17470   2008   P80003353  N00000286         Mitt Romney (R)     R
# 35715  20027   2008   S0NY00170  N00009908  Rudolph W Giuliani (R)     R
# 6620   19883   2008   P00003251  N00009908  Rudolph W Giuliani (R)     R
#
#       dist_id_run_for dist_id_currently_held current_candidate  \
# 43213            PRES                                        Y
# 37682            PRES                   AZS1                 Y
# 42665            PRES                   AZS1
# 11245            PRES                   PRES                 Y
# 39207            PRES                                        Y
# 14064            PRES
# 3036             PRES
# 3037             PRES
# 35715            PRES
# 6620             PRES
#
#       cycle_candidate crpico recip_code nopacs  raised_from_pacs  \
# 43213               Y      C         RL               92835231.0
# 37682               Y      O         RL               26767631.0
# 42665                      O         RL               26767631.0
# 11245               Y      I         RW               37621914.0
# 39207               Y      O         RW               23158024.0
# 14064               Y      O         RL                   1723.0
# 3036                       O         RO                 464481.0
# 3037                Y      O         RL                 464481.0
# 35715                      O         RO                2310906.0
# 6620                Y      O         RL                2310906.0
#
#        raised_from_individuals  raised_total  raised_unitemized
# 43213              355605910.0     473940398         25499257.0
# 37682              166651506.0     243052415         49633278.0
# 42665              166651506.0     243052415         49633278.0
# 11245              186886583.0     224508497                0.0
# 39207               81353631.0     104511655                NaN
# 14064               82263302.0      82265025                0.0
# 3036                54484163.0      54948644                0.0
# 3037                54484163.0      54948644                0.0
# 35715               48170423.0      50481329                0.0
# 6620                48170423.0      50481329                0.0

# %%
# Top corporate donors by millions of dollars
pac_to_pacs['amount_mil'] = pac_to_pacs['amount']/1_000_000
pac_to_pacs.groupby(by='donor_committee')[['amount_mil']].mean().sort_values(by='amount_mil', ascending=False).head(20)
# Out:
#                               amount_mil
# donor_committee
# BANK OF AMERICA, NA            12.000000
# BANK OF GEORGETOWN              6.666667
# AMALGAMATED BANK OF NEW YORK    6.166667
# WELLS FARGO                     6.000000
# SUMMIT BANK                     5.781316
# SMITH, THOMAS                   4.225000
# SOROS, GEORGE                   3.275000
# Feinstein, Dianne               3.180000
# Watts, Mikal                    2.797334
# BING, STEVE                     2.746194
# Romney Victory                  2.629107
# Romney, Mitt                    2.623529
# Bank of America, NA             2.566667
# McCain-Palin 2008               2.324921
# Hull, Blair                     2.216667
# BANK OF AMERICA-LOC             2.092857
# CHAIN BRIDGE BANK               2.000000
# Ciresi, Michael V               2.000000
# GOLDMAN SACHS & CO.             2.000000
# Obama Victory Fund              1.774419
