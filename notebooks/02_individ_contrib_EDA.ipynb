# %% [markdown]
# <center>
#     <h2>Individual Contributions</h2>
#     <h3>Exploratory Data Analysis</h3><br>
# </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# %time df = pd.read_csv('../data/individual_contributions.csv', low_memory=False)
# Out:
# CPU times: user 2min 53s, sys: 1min 7s, total: 4min
# Wall time: 4min 33s

# %%
def add_commas(number):
    n = str(number)
    
    if len(n)>6:
        return n[:-6]+','+n[-6:-3]+','+n[-3:]
    elif len(n)>3:
        return n[:-3]+','+n[-3:]
    else:
        return number

# %%
(add_commas(df.shape[0]), df.shape[1])
# Out:
# ('24,446,378', 25)

# %%
df.columns
# Out:
# Index(['id', 'cycle', 'fec_trans_id', 'contributor_id', 'contributor_name',
#        'recipient_id', 'org_name', 'ult_org', 'real_code', 'date', 'amount',
#        'street', 'city', 'state', 'zip', 'recip_code', 'type', 'committee_id',
#        'other_id', 'gender', 'old_format_employer_occupation', 'microfilm',
#        'occupation', 'employer', 'source'],
#       dtype='object')

# %%
df['amount_mil'] = df['amount'] / 1_000_000

df.sort_values(by='amount_mil', ascending=False)[[
    'contributor_name', 'amount_mil']].drop_duplicates('contributor_name').head(20)
# Out:
#                             contributor_name  amount_mil
# 5457875                  MERCER, LEE L MR JR   24.000000
# 5636195                     STEYER, THOMAS F   16.000000
# 24037919                    UNITEMIZED TOTAL   10.465912
# 23958197                    NEUGEBAUER, TOBY   10.000000
# 5905890                                  NaN    9.350125
# 828934     AMERICANS FOR TAX REFORM (GENERAL    7.674142
# 8191697                       SABAN, HAIM MR    7.000000
# 10766216               VICTORY CAMPAIGN 2004    6.150000
# 18705225                      MCMAHON, LINDA    6.000000
# 8346487   DEMOCRATIC SENATORIAL CAMPAIGN COM    5.958333
# 2527621                      RICKETTS, J JOE    5.486382
# 18828209                      FIORINA, CARLY    5.289500
# 813573                         HUNTSMAN, JON    5.139481
# 1255015                   ADELSON, MIRIAM DR    5.000000
# 3038271                   ADELSON, SHELDON G    5.000000
# 23949193               HENDRICKS, DIANE M MS    5.000000
# 3245001                      ADELSON, MIRIAM    5.000000
# 3533085                     ADELSON, SHELDON    5.000000
# 5392909       NATIONAL EDUCATION ASSOCIATION    5.000000
# 24139745                     WARREN, KELCY L    5.000000

# %% [markdown]
# ---
# ## Party Committees (including loans)

# %%
party = []

for code in df['recip_code']:
    if str(code).upper()[0] == 'D':
        party.append('D')
    elif str(code).upper()[0] == 'R':
        party.append('R')
    else:
        party.append(np.nan)
        
df['party'] = party

# %%
df['party'].value_counts(normalize=True) # Near-even split between parties
# Out:
# R    0.501228
# D    0.498772
# Name: party, dtype: float64

# %%
df['committee'] = [1 if str(code).upper()[-1] == 'P' else 0 for code in df['recip_code']]

# %%
cols_to_filter = [
    'cycle', 'contributor_name', 'org_name', 'ult_org', 'amount', 'city', 'state', 'recip_code', 'type',
    'employer', 'source']

# %%
# Top Donations from Republican Committees
df[(df['committee']==1)&(df['party']=='R')][cols_to_filter].sort_values(
    by='amount', ascending=False).drop_duplicates('contributor_name').head(10)
# Out:
#           cycle                 contributor_name  \
# 19748559   1992             SIGNET BANK/VIRGINIA
# 8970891    2002           TEXANS FOR JOHN CORNYN
# 7609801    2002      PRESIDENTIAL INAUGURAL COMM
# 8902096    2002  REPUBLICAN GOVERNORS ASSOCATION
# 7844441    2002    REPUBLICAN NATIONAL COMMITTEE
# 7833448    2002              NATIONAL REPUBLICAN
# 21287964   1994                AMWAY CORPORATION
# 22536993   1996                      SIGNET BANK
# 22614768   1996          NEW YORK REP STATE CMTE
# 8490580    2002     2002 PRESIDENT'S DINNER CMTE
#
#                                 org_name ult_org   amount        city state  \
# 19748559                   Loan Proceeds     NaN  4500000      VIENNA    VA
# 8970891           Texans for John Cornyn     NaN  3100000      AUSTIN    TX
# 7609801      Presidential Inaugural Cmte     NaN  2057560  WASHINGTON    DC
# 8902096        Republican Governors Assn     NaN  2000000  WASHINGTON    DC
# 7844441         Republican National Cmte     NaN  2000000  WASHINGTON    DC
# 7833448              National Republican     NaN  1700000  WASHINGTON    DC
# 21287964                      Amway Corp   Amway  1700000         ADA    MI
# 22536993                     Signet Bank     NaN  1700000    RICHMOND    VA
# 22614768  New York Republican State Cmte     NaN  1500000      ALBANY    NY
# 8490580     2002 President's Dinner Cmte     NaN  1061400  WASHINGTON    DC
#
#          recip_code type employer source
# 19748559         RP  10       NaN  Rept
# 8970891          RP  10       NaN  Name
# 7609801          RP  10       NaN  Rept
# 8902096          RP  10       NaN  Name
# 7844441          RP  10       NaN  Rept
# 7833448          RP  10       NaN  Rept
# 21287964         RP  10       NaN  PAC
# 22536993         RP  10       NaN  Rept
# 22614768         RP  10       NaN  Name
# 8490580          RP  10       NaN  Rept

# %%
# Top Donations from Democrat Committees
df[(df['committee']==1)&(df['party']=='D')][cols_to_filter].sort_values(
    by='amount', ascending=False).drop_duplicates('contributor_name').head(10)
# Out:
#           cycle                    contributor_name  \
# 8191697    2002                      SABAN, HAIM MR
# 8346487    2002  DEMOCRATIC SENATORIAL CAMPAIGN COM
# 8615952    2002                   EYCHANER, FRED MR
# 8191690    2002                  BING, STEPHEN L MR
# 7469205    2000                     BANK OF AMERICA
# 7248396    2000   DCCC UNINCORPORATED RECEIPTS ACCT
# 7280392    2000          DCCC NONFEDERAL RECEIPTS-L
# 7469206    2000       DNC NON-FEDERAL UNINCORPORATE
# 7247944    2000          DCCC NONFEDERAL RECEIPTS-C
# 21147284   1994                     NATIONSBANK N A
#
#                                      org_name                   ult_org  \
# 8191697                   Saban Capital Group                       NaN
# 8346487   Democratic Senatorial Campaign Cmte                       NaN
# 8615952                          Newsweb Corp                       NaN
# 8191690              Shangri-La Entertainment                       NaN
# 7469205                       Bank of America                       NaN
# 7248396     DCCC Unincorporated Receipts Acct                       NaN
# 7280392            DCCC/Non-Federal Account L                       NaN
# 7469206        DNC Non-Federal Unincorporated  Democratic National Cmte
# 7247944            DCCC/Non-Federal Account C                       NaN
# 21147284                     NationsBank LOAN                       NaN
#
#            amount         city state recip_code type employer source
# 8191697   7000000  LOS ANGELES    CA         DP  10       NaN  WebSK
# 8346487   5958333   WASHINGTON    DC         DP  10       NaN  Rept
# 8615952   3000000      CHICAGO    IL         DP  10       NaN  WebPN
# 8191690   3000000  LOS ANGELES    CA         DP  10       NaN  I/Nam
# 7469205   2500000   WASHINGTON    DC         DP  10       NaN  Rept
# 7248396   2000000   WASHINGTON    DC         DP  10       NaN  Rept
# 7280392   2000000   WASHINGTON    DC         DP  10       NaN  Rept
# 7469206   2000000          NaN               DP  10       NaN  Rept
# 7247944   2000000   WASHINGTON    DC         DP  10       NaN  Rept
# 21147284  1750000   WASHINGTON    DC         DP  10       NaN  Rept

# %%
df[df['committee']==1].groupby(
    by=['party', 'cycle'])[['amount_mil']].sum().sort_values(by=['cycle', 'party'], ascending=False)
# Out:
#               amount_mil
# party cycle
# R     2016    131.972892
# D     2016     68.568677
# R     2014    334.311565
# D     2014    278.874910
# R     2012   1001.230353
# D     2012    778.328186
# R     2010    217.838172
# D     2010    271.818905
# R     2008    599.295368
# D     2008    575.606451
# R     2006    264.557316
# D     2006    205.546737
# R     2004    384.814137
# D     2004    341.636006
# R     2002    443.927842
# D     2002    395.897022
# R     2000    440.063588
# D     2000    448.361414
# R     1998    207.152140
# D     1998    150.962738
# R     1996    275.947450
# D     1996    205.945160
# R     1994    116.509857
# D     1994     95.082835
# R     1992    149.592486
# D     1992     99.389807
# R     1990     62.032612
# D     1990     14.342681

# %% [markdown]
# ---
# ## Corporate Donations (Business, Labor, Single-Issue)

# %%
df['recip_code'].unique()
# Out:
# array(['DI', 'DP', 'RP', 'DL', 'DW', 'RN', 'PI', 'RL', 'RW', '3N', 'PB',
#        'DC', '3L', '3W', 'DN', 'RI', 'OI', 'UN', 'RC', '3C', 'PL', 'PU',
#        '3P', '3O', 'RO', 'DO', '3I', 'OB', 'OU', nan, 'PO', 'OL', 'R ',
#        'Pi', '  ', 'UO', 'Rw', 'Dw', '3l', 'UL'], dtype=object)

# %%
df['pac'] = [1 if str(code).upper()[0] == 'P' else 0 for code in df['recip_code']]

# %%
df['pac'].sum() / len(df['pac']) # 17% of donations are PACs
# Out:
# 0.17190730667749635

# %%
issue = []

for code in df['recip_code']:
    if str(code).upper()[-1] == 'B':
        issue.append('business')
    elif (str(code).upper() == 'PL') or (str(code).upper() == 'OL'):
        issue.append('labor')
    elif str(code).upper()[-1] == 'I':
        issue.append('ideological')
    elif str(code).upper()[-1] == 'O':
        issue.append('other')
    else:
        issue.append(np.nan)
        
df['issue'] = issue

# %%
df['issue'].value_counts(normalize=True)
# Out:
# business       0.504732
# ideological    0.388650
# other          0.072068
# labor          0.034550
# Name: issue, dtype: float64

# %%
# 23 % of donations are issue-based
df['issue'].notna().sum() / len(df['issue'])
# Out:
# 0.22983515185766987

# %%
# Top Donations in Business Category
df[df['issue']=='business'][cols_to_filter].sort_values(
    by='amount', ascending=False).drop_duplicates('contributor_name').head(10)
# Out:
#           cycle                                   contributor_name  \
# 5333041    2014                  ASSOCIATION OF REALTORS, NATIONAL
# 6855819    2000                   AMERICAN MEDICAL ASSOCIATION PAC
# 1168737    2012                 COOPERATIVE OF AMERICAN PHYSICIANS
# 18733061   2010                   REPUBLICAN GOVERNORS ASSOCIATION
# 2578104    2012  BIPAC - BUSINESS INSTITUTE FOR POLITICAL ANALYSIS
# 7539846    2000                   CALIFORNIA MEDICAL PAC STATE PAC
# 6253430    2000                                              AMPAC
# 19716727   1992                                                NaN
# 2401259    2012                               ADPAC EDUCATION FUND
# 21557074   1996                 AMERICAN DENTAL PAC EDUCATION FUND
#
#                                     org_name ult_org   amount         city  \
# 5333041            National Assn of Realtors     NaN  3881731      CHICAGO
# 6855819                   [24T Contribution]     NaN  1500150          NaN
# 1168737   Cooperative of American Physicians     NaN  1169070  LOS ANGELES
# 18733061                                 NaN     NaN  1138000   WASHINGTON
# 2578104                                  NaN     NaN   250000   WASHINGTON
# 7539846                   [24T Contribution]     NaN   215000          NaN
# 6253430                   [24T Contribution]     NaN   176650          NaN
# 19716727                  [24T Contribution]     NaN   164680          NaN
# 2401259                 American Dental Assn     NaN   126500   WASHINGTON
# 21557074                  [24T Contribution]     NaN   125000          NaN
#
#          state recip_code type     employer source
# 5333041     IL         OB  10   CORPORATION  Name
# 6855819                PB  24T          NaN  Rept
# 1168737     CA         OB  10           NaN  PAC
# 18733061    DC         OB  10           NaN  P/PAC
# 2578104     DC         PB  10           NaN  P/PAC
# 7539846                PB  24T          NaN  Rept
# 6253430                PB  24T          NaN  Rept
# 19716727               PB  24T          NaN  Rept
# 2401259     DC         OB  10           NaN  PAC
# 21557074               PB  24T          NaN  Rept

# %%
# Top Donations in Labor Category
df[df['issue']=='labor'][cols_to_filter].sort_values(
    by='amount', ascending=False).drop_duplicates('contributor_name').head(10)
# Out:
#           cycle                                  contributor_name  \
# 5392909    2014                    NATIONAL EDUCATION ASSOCIATION
# 5720193    2014                             AFL-CIO COPE TREASURY
# 3497633    2012                            AFSCME SPECIAL ACCOUNT
# 3464897    2012                          INTERNATIONAL UNION, UAW
# 5554058    2014                            NATIONAL NURSES UNITED
# 5390949    2014          NEA FUND FOR CHILDREN & PUBLIC EDUCATION
# 3475506    2012                                           AFL-CIO
# 18736746   2010                CARPENTERS DISTRICT COUNCIL OF KAN
# 4592181    2014      UNITED BROTHERHOOD OF CARPENTERS AND JOINERS
# 955488     2012  COMMITTEE ON LETTER CARRIERS POLITICAL EDUCATION
#
#                                           org_name                  ult_org  \
# 5392909                    National Education Assn                      NaN
# 5720193                                    AFL-CIO                      NaN
# 3497633   American Fedn of St/Cnty/Munic Employees                      NaN
# 3464897   United Auto Workers                                           NaN
# 5554058                     National Nurses United                      NaN
# 5390949   NEA Fund for Children & Public Education  National Education Assn
# 3475506                                    AFL-CIO                      NaN
# 18736746                                       NaN                      NaN
# 4592181                 Carpenters & Joiners Union                      NaN
# 955488            National Assn of Letter Carriers                      NaN
#
#            amount           city state recip_code type employer source
# 5392909   5000000     WASHINGTON    DC         OL  10       NEA  PAC
# 5720193   3000000     WASHINGTON    DC         OL  10       NaN  PAC
# 3497633   1832111     WASHINGTON    DC         OL  10       NaN  PAC
# 3464897   1402000        DETROIT    MI         OL  10       NaN  PAC
# 5554058   1367000  SILVER SPRING    MD         OL  10       NaN  PAC
# 5390949   1200000     WASHINGTON    DC         OL  10       NaN  Rept
# 3475506   1002868     WASHINGTON    DC         OL  10       NaN  PAC
# 18736746   972578    KANSAS CITY    MO         OL  10       NaN  P/PAC
# 4592181    757236     WASHINGTON    DC         OL  10       NaN  PAC
# 955488     713919     WASHINGTON    DC         OL  10       NaN  PAC
